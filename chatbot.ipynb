# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import nltk
nltk.download('punkt')
import nltk
nltk.download('wordnet')

from nltk import word_tokenize,sent_tokenize

import numpy as np
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import gradient_descent_v2
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = gradient_descent_v2.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# 41 documents
# 9 classes ['blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'robot', 'thanks']
# 75 unique lemmatized words ["'s", ',', 'a', 'anyone', 'are', 'awesome', 'blood', 'by', 'bye', 'chatting', 'data', 'day', 'detail', 'do', 'entry', 'family', 'find', 'for', 'good', 'goodbye', 'have', 'hello', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'human', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'mother', 'name', 'nearby', 'next', 'nice', 'of', 'open', 'patient', 'pharmacy', 'pressure', 'related', 'result', 'robot', 'search', 'searching', 'see', 'show', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'you', 'your']
# Training data created
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fc8c072d0d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fc8c072d0d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [nltk_data] Downloading package punkt to /Users/siri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/siri/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /var/folders/48/wwsljxtn1slgz5lk6l8qc0dc0000gn/T/ipykernel_15472/2823936845.py:80: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# 9/9 [==============================] - 1s 2ms/step - loss: 2.2501 - accuracy: 0.0488
# Epoch 2/200
# 9/9 [==============================] - 0s 2ms/step - loss: 2.2035 - accuracy: 0.1707
# Epoch 3/200
# 9/9 [==============================] - 0s 2ms/step - loss: 2.1274 - accuracy: 0.1951
# Epoch 4/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.9638 - accuracy: 0.3171
# Epoch 5/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.8830 - accuracy: 0.3902
# Epoch 6/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.7456 - accuracy: 0.3659
# Epoch 7/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.7176 - accuracy: 0.4634
# Epoch 8/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.6238 - accuracy: 0.5122
# Epoch 9/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.4963 - accuracy: 0.5366
# Epoch 10/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.4233 - accuracy: 0.5366
# Epoch 11/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.2504 - accuracy: 0.6341
# Epoch 12/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.2753 - accuracy: 0.5610
# Epoch 13/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1343 - accuracy: 0.6585
# Epoch 14/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.0880 - accuracy: 0.6341
# Epoch 15/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.9561 - accuracy: 0.7073
# Epoch 16/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1311 - accuracy: 0.7073
# Epoch 17/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.9293 - accuracy: 0.6829
# Epoch 18/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.8059 - accuracy: 0.8293
# Epoch 19/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.9130 - accuracy: 0.7073
# Epoch 20/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.8425 - accuracy: 0.7805
# Epoch 21/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.8494 - accuracy: 0.7561
# Epoch 22/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.8780
# Epoch 23/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7656 - accuracy: 0.7317
# Epoch 24/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.8293
# Epoch 25/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5548 - accuracy: 0.8049
# Epoch 26/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5869 - accuracy: 0.7805
# Epoch 27/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6510 - accuracy: 0.8049
# Epoch 28/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.8537
# Epoch 29/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2845 - accuracy: 0.9512
# Epoch 30/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6327 - accuracy: 0.8293
# Epoch 31/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.9024
# Epoch 32/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8780
# Epoch 33/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.9512
# Epoch 34/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3114 - accuracy: 0.8537
# Epoch 35/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3145 - accuracy: 0.9512
# Epoch 36/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2367 - accuracy: 0.9756
# Epoch 37/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2859 - accuracy: 0.9512
# Epoch 38/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3013 - accuracy: 0.9268
# Epoch 39/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.8780
# Epoch 40/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2906 - accuracy: 0.9268
# Epoch 41/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2781 - accuracy: 0.9268
# Epoch 42/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3064 - accuracy: 0.8780
# Epoch 43/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2824 - accuracy: 0.9024
# Epoch 44/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3133 - accuracy: 0.9268
# Epoch 45/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1177 - accuracy: 0.9756
# Epoch 46/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1834 - accuracy: 0.9268
# Epoch 47/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2222 - accuracy: 0.9512
# Epoch 48/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1787 - accuracy: 1.0000
# Epoch 49/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.9512
# Epoch 50/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 51/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2481 - accuracy: 0.9512
# Epoch 52/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 1.0000
# Epoch 53/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1676 - accuracy: 0.9512
# Epoch 54/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0955 - accuracy: 0.9756
# Epoch 55/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0789 - accuracy: 1.0000
# Epoch 56/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1737 - accuracy: 0.9024
# Epoch 57/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1808 - accuracy: 0.9268
# Epoch 58/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0993 - accuracy: 0.9756
# Epoch 59/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1926 - accuracy: 0.9024
# Epoch 60/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1850 - accuracy: 0.9268
# Epoch 61/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2117 - accuracy: 0.9512
# Epoch 62/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1149 - accuracy: 0.9512
# Epoch 63/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1895 - accuracy: 0.9512
# Epoch 64/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0879 - accuracy: 0.9756
# Epoch 65/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1615 - accuracy: 0.9756
# Epoch 66/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9756
# Epoch 67/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1157 - accuracy: 1.0000
# Epoch 68/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0795 - accuracy: 0.9756
# Epoch 69/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 0.9756
# Epoch 70/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1255 - accuracy: 0.9756
# Epoch 71/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0834 - accuracy: 0.9756
# Epoch 72/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 73/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9756
# Epoch 74/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.9512
# Epoch 75/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1573 - accuracy: 0.9756
# Epoch 76/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9756
# Epoch 77/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1798 - accuracy: 0.9512
# Epoch 78/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0828 - accuracy: 0.9756
# Epoch 79/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1098 - accuracy: 0.9756
# Epoch 80/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 81/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1902 - accuracy: 0.9268
# Epoch 82/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0888 - accuracy: 0.9756
# Epoch 83/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 84/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1155 - accuracy: 0.9756
# Epoch 85/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0498 - accuracy: 0.9756
# Epoch 86/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 87/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 1.0000
# Epoch 88/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 89/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 90/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.9512
# Epoch 91/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 92/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.9756
# Epoch 93/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0680 - accuracy: 0.9756
# Epoch 94/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9512
# Epoch 95/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 0.9756
# Epoch 96/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1068 - accuracy: 0.9512
# Epoch 97/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 0.9756
# Epoch 98/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 99/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0699 - accuracy: 0.9756
# Epoch 100/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 101/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 102/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9756
# Epoch 103/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 104/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 105/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 106/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0575 - accuracy: 1.0000
# Epoch 107/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0907 - accuracy: 0.9756
# Epoch 108/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9512
# Epoch 109/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 110/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 111/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9756
# Epoch 112/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0602 - accuracy: 1.0000
# Epoch 113/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 114/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 0.9756
# Epoch 115/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9268
# Epoch 116/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 117/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 118/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9512
# Epoch 119/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 120/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 121/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 122/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 123/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 124/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 125/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 126/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 127/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 128/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 0.9756
# Epoch 129/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 130/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 131/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 132/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 133/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0749 - accuracy: 0.9512
# Epoch 134/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 135/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 136/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1032 - accuracy: 0.9512
# Epoch 137/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 138/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9756
# Epoch 139/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 140/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9756
# Epoch 141/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 142/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 143/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9756
# Epoch 144/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9756
# Epoch 145/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.9756
# Epoch 146/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 147/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 148/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 1.0000
# Epoch 149/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 1.0000
# Epoch 150/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0703 - accuracy: 1.0000
# Epoch 151/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 152/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9756
# Epoch 153/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 154/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 155/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 156/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0575 - accuracy: 0.9756
# Epoch 157/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 158/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 159/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 160/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 161/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1194 - accuracy: 0.9512
# Epoch 162/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 163/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0347 - accuracy: 0.9756
# Epoch 164/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 165/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9756
# Epoch 166/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 0.9756
# Epoch 167/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 168/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 169/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 170/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0612 - accuracy: 0.9756
# Epoch 171/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 0.9756
# Epoch 172/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9512
# Epoch 173/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 174/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 175/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 176/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 177/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 178/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 179/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0425 - accuracy: 0.9756
# Epoch 180/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 181/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 182/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 183/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 184/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 185/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 186/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 187/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 188/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0962 - accuracy: 0.9756
# Epoch 189/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 190/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 191/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 192/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 193/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 194/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 195/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 196/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 197/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 198/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 199/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 200/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0435 - accuracy: 0.9756
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))


def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res


#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
    
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
            
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
 

base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="blue", activebackground="blue",fg='blue',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)


base.mainloop()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fc8c0740dc0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fc8c0740dc0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
